# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the file in dataframe
df = pd.read_csv("Netflix.csv")
df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
#Describing total rows and columns
df.shape
# Out:
# (6234, 12)

# %%
#Summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
#Total types 
df.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
#types ni count
df0=df.type.value_counts()
df0
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
#Plotting in graph
df1=df0.plot(kind='bar', figsize=(10,6))
df1.set_title('What is more in Netflix?')
# Out:
# Text(0.5, 1.0, 'What is more in Netflix?')

# %%
#listed _in counts
df1=df.listed_in.value_counts()
df1
# Out:
# Documentaries                                                  299
# Stand-Up Comedy                                                273
# Dramas, International Movies                                   248
# Dramas, Independent Movies, International Movies               186
# Comedies, Dramas, International Movies                         174
#                                                               ...
# Romantic TV Shows, TV Dramas, TV Sci-Fi & Fantasy                1
# International TV Shows, TV Action & Adventure, TV Mysteries      1
# British TV Shows, Kids' TV, TV Dramas                            1
# Kids' TV, Reality TV, Science & Nature TV                        1
# Anime Features, Romantic Movies                                  1
# Name: listed_in, Length: 461, dtype: int64

# %%
# Deep filtering
df_documentries = df[df.listed_in=="Documentaries"]
df_documentries
# Out:
#        show_id   type                                             title  \
# 22    80046727  Movie                                    Rolling Papers
# 27    80203094  Movie                                       City of Joy
# 43    80095641  Movie                                      Elstree 1976
# 44    81176188  Movie  American Factory: A Conversation with the Obamas
# 73    80081155  Movie                                       Amanda Knox
# ...        ...    ...                                               ...
# 5564  70129457  Movie                                          Life 2.0
# 5570  80104318  Movie                                   Silicon Cowboys
# 5572  80097468  Movie                                      The Bad Kids
# 5577  80085438  Movie                                   Frank and Cindy
# 5580  80064521  Movie               Jeremy Scott: The People's Designer
#
#                           director  \
# 22                   Mitch Dickman
# ...

# %%
#searching from required range
df1 = df_documentries['release_year'] 
df1 = df_documentries[df_documentries.release_year > 2014 ]['release_year'] 
sns.distplot(df1)
plt.show()

# %%
df_documentries['duration']
# Out:
# 22       79 min
# 27       77 min
# 43      102 min
# 44       10 min
# 73       92 min
#          ...
# 5564     99 min
# 5570     77 min
# 5572    101 min
# 5577     70 min
# 5580    109 min
# Name: duration, Length: 299, dtype: object

# %%
df_documentries.sort_values('release_year',ascending=True)
# Out:
#        show_id   type                                title  \
# 2023  70013050  Movie   Why We Fight: The Battle of Russia
# 2026  70022548  Movie      WWII: Report from the Aleutians
# 3332  80045818  Movie    Auschwitz: Blueprints of Genocide
# 5161  80106144  Movie                      Children of God
# 1026  60024976  Movie             Jerry Seinfeld: Comedian
# ...        ...    ...                                  ...
# 1659  81002195  Movie                          After Maria
# 4153  81212801  Movie        The Irishman: In Conversation
# 2669  81147766  Movie  Oprah Presents When They See Us Now
# 4878  81090071  Movie                     American Factory
# 557   80186796  Movie               Dancing with the Birds
#
#                            director  \
# 2023    Frank Capra, Anatole Litvak
# 2026                    John Huston
# 3332                  Mike Rossiter
# 5161                  John Smithson
# 1026              Christian Charles
# ...
